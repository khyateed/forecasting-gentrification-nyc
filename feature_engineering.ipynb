# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
filename = 'Data/Cleaned/postprocessed.pkl'
with open(filename, mode='rb') as f:
    df = pickle.load(f)
df.sample()
# Out:
#                                            NAME  percent_white  percent_black  \
# 7742  Census Tract 645, Queens County, New York       0.579151       0.040058
#
#       percent_native  percent_asian  percent_pacific  percent_latino  \
# 7742        0.002413       0.271718              0.0        0.236486
#
#       percent_bachelors  percent_grad  percent_instate  ...  percent_rented  \
# 7742            0.30432      0.208253         0.344112  ...        0.410014
#
#       med_value  year  med_hh_age med_hh_residence  full_tract  \
# 7742   684100.0  2018         0.0             18.0   081064500
#
#       Proportion_citibike_rides num_trees     med_rent        GEOID
# 7742                        0.0     394.0  2087.729817  36081064500
#
# [1 rows x 22 columns]

# %% [markdown]
# ## Generate Features for X-Year Percent Change
# - train on features 2010-2016 to predict gentrification status in 2020 (labels from 2020, eligible tracts from 2010)
# - train on features 2012-2018 to predict gentrification status in 2022 (labels from 2022, eligible tracts from 2012)
#
# - then use features 2016-2022 to predict gentrification status in 2026 (no labels, eligible tracts are taken from 2016)

# %%
df_10_16 = df[df.year.isin(['2010','2011','2012','2013','2014','2015','2016'])]  # training set
df_12_18 = df[df.year.isin(['2012','2013','2014','2015','2016','2017','2018'])]  # training set
df_16_22 = df[df.year.isin(['2016','2017','2018','2019','2020','2021','2022'])]  # pred set

# %%
# TODO we have missing years which will mess up calculation of pct change. need to interpolate missing years

df_10_16 = df_10_16.drop(['NAME','year', 'full_tract'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().mean())
df_12_18 = df_12_18.drop(['NAME','year', 'full_tract'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().mean())
df_16_22 = df_16_22.drop(['NAME','year', 'full_tract'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().mean())

df_10_16['pred_year']='2020'
df_12_18['pred_year']='2022'
df_16_22['pred_year']='2026'

# %%
df_train = pd.concat([df_10_16, df_12_18, df_16_22])
df_train
# Out:
#              percent_white  percent_black  percent_native  percent_asian  \
# GEOID
# 36005000200       0.253498      -0.069683       -0.158731       0.045475
# 36005000400       0.401586       0.111454             inf      -0.076004
# 36005001600       0.206153       0.006892             NaN            NaN
# 36005001900      -0.231540       0.134766             NaN       0.140154
# 36005002000       0.266932       0.031160             inf            inf
# ...                    ...            ...             ...            ...
# 36085030301      -0.000015      -0.372741             inf       0.097769
# 36085030302      -0.058056       0.192520             NaN       0.072049
# 36085031901       0.093828      -0.057249             NaN       0.079193
# 36085031902      -0.109198      -0.011178             inf       0.609157
# 36085032300      -0.077688      -0.019123       -1.000000            inf
#
#              percent_pacific  percent_latino  percent_bachelors  percent_grad  \
# GEOID
# 36005000200              NaN        0.013086           0.054308     -0.001092
# 36005000400              NaN       -0.024307          -0.021735      0.022121
# 36005001600              NaN        0.016500           0.028395     -0.077970
# 36005001900              NaN       -0.040426           0.062270      0.037248
# 36005002000              NaN        0.007742           0.063012     -0.179134
# ...                      ...             ...                ...           ...
# 36085030301              NaN       -0.002331           0.085906     -0.037404
# 36085030302              NaN       -0.111086           0.045027     -0.021830
# 36085031901              NaN        0.034899          -0.012391      0.576102
# 36085031902              NaN        0.016932           0.054347     -0.031721
# 36085032300              NaN        0.030812           0.092259      0.477841
#
#              percent_instate  med_income  percent_owned  percent_rented  \
# GEOID
# 36005000200         0.004986    0.039653      -0.097196             inf
# 36005000400         0.007430    0.016922      -0.039718             inf
# 36005001600        -0.066064    0.009668      -0.185730        1.482936
# 36005001900         0.195301    0.049870      -0.275184        0.090376
# 36005002000        -0.056130   -0.088320      -0.196227             inf
# ...                      ...         ...            ...             ...
# 36085030301         0.024439    0.132738       0.008724        0.001863
# 36085030302         0.051280    0.090315       0.036488       -0.107441
# 36085031901         0.118195    0.488474       0.071542       -0.022689
# 36085031902         0.007832    0.168562       0.043006       -0.038730
# 36085032300        -0.008452    0.069476       0.014091        0.031205
#
#              med_value  med_hh_age  med_hh_residence  \
# GEOID
# 36005000200   0.011581   -0.026547         -0.016797
# 36005000400  -0.025644   -0.091655         -0.023268
# 36005001600   0.004031   -0.021844         -0.050903
# 36005001900   0.025174   -0.107038         -0.062557
# 36005002000  -0.004516    0.003948         -0.067870
# ...                ...         ...               ...
# 36085030301   0.082799    0.000000         -0.041210
# 36085030302   0.113577   -0.024206         -0.048465
# 36085031901  -0.014634    0.011404         -0.025731
# 36085031902   0.090462   -0.022576         -0.033905
# 36085032300   0.034731    0.011258          0.000487
#
#              Proportion_citibike_rides  num_trees  med_rent pred_year
# GEOID
# 36005000200                        NaN   0.040706  0.000000      2020
# 36005000400                        NaN   0.099676  0.000000      2020
# 36005001600                        NaN   0.076535  0.000000      2020
# 36005001900                        NaN        NaN  0.000000      2020
# 36005002000                        NaN        NaN  0.000000      2020
# ...                                ...        ...       ...       ...
# 36085030301                        NaN   0.021161  0.016526      2026
# 36085030302                        NaN   0.004528  0.022034      2026
# 36085031901                        NaN   0.054600  0.000000      2026
# 36085031902                        NaN   0.040412  0.000000      2026
# 36085032300                        NaN  -0.019439  0.011017      2026
#
# [6546 rows x 19 columns]

# %%
# drop rows that became entirely null bc of the pairwise % change
df_train.dropna(how='all',subset=['percent_white', 'percent_black',
       'percent_native', 'percent_asian', 'percent_pacific', 'percent_latino',
       'percent_bachelors', 'percent_grad', 'percent_instate', 'med_income',
       'percent_owned', 'percent_rented', 'med_value', 'med_hh_age',
       'med_hh_residence', 'Proportion_citibike_rides', 'num_trees'], inplace=True)

df_train.fillna(0, inplace=True)
df_train
# Out:
#              percent_white  percent_black  percent_native  percent_asian  \
# GEOID
# 36005000200       0.253498      -0.069683       -0.158731       0.045475
# 36005000400       0.401586       0.111454             inf      -0.076004
# 36005001600       0.206153       0.006892        0.000000       0.000000
# 36005001900      -0.231540       0.134766        0.000000       0.140154
# 36005002000       0.266932       0.031160             inf            inf
# ...                    ...            ...             ...            ...
# 36085030301      -0.000015      -0.372741             inf       0.097769
# 36085030302      -0.058056       0.192520        0.000000       0.072049
# 36085031901       0.093828      -0.057249        0.000000       0.079193
# 36085031902      -0.109198      -0.011178             inf       0.609157
# 36085032300      -0.077688      -0.019123       -1.000000            inf
#
#              percent_pacific  percent_latino  percent_bachelors  percent_grad  \
# GEOID
# 36005000200              0.0        0.013086           0.054308     -0.001092
# 36005000400              0.0       -0.024307          -0.021735      0.022121
# 36005001600              0.0        0.016500           0.028395     -0.077970
# 36005001900              0.0       -0.040426           0.062270      0.037248
# 36005002000              0.0        0.007742           0.063012     -0.179134
# ...                      ...             ...                ...           ...
# 36085030301              0.0       -0.002331           0.085906     -0.037404
# 36085030302              0.0       -0.111086           0.045027     -0.021830
# 36085031901              0.0        0.034899          -0.012391      0.576102
# 36085031902              0.0        0.016932           0.054347     -0.031721
# 36085032300              0.0        0.030812           0.092259      0.477841
#
#              percent_instate  med_income  percent_owned  percent_rented  \
# GEOID
# 36005000200         0.004986    0.039653      -0.097196             inf
# 36005000400         0.007430    0.016922      -0.039718             inf
# 36005001600        -0.066064    0.009668      -0.185730        1.482936
# 36005001900         0.195301    0.049870      -0.275184        0.090376
# 36005002000        -0.056130   -0.088320      -0.196227             inf
# ...                      ...         ...            ...             ...
# 36085030301         0.024439    0.132738       0.008724        0.001863
# 36085030302         0.051280    0.090315       0.036488       -0.107441
# 36085031901         0.118195    0.488474       0.071542       -0.022689
# 36085031902         0.007832    0.168562       0.043006       -0.038730
# 36085032300        -0.008452    0.069476       0.014091        0.031205
#
#              med_value  med_hh_age  med_hh_residence  \
# GEOID
# 36005000200   0.011581   -0.026547         -0.016797
# 36005000400  -0.025644   -0.091655         -0.023268
# 36005001600   0.004031   -0.021844         -0.050903
# 36005001900   0.025174   -0.107038         -0.062557
# 36005002000  -0.004516    0.003948         -0.067870
# ...                ...         ...               ...
# 36085030301   0.082799    0.000000         -0.041210
# 36085030302   0.113577   -0.024206         -0.048465
# 36085031901  -0.014634    0.011404         -0.025731
# 36085031902   0.090462   -0.022576         -0.033905
# 36085032300   0.034731    0.011258          0.000487
#
#              Proportion_citibike_rides  num_trees  med_rent pred_year
# GEOID
# 36005000200                        0.0   0.040706  0.000000      2020
# 36005000400                        0.0   0.099676  0.000000      2020
# 36005001600                        0.0   0.076535  0.000000      2020
# 36005001900                        0.0   0.000000  0.000000      2020
# 36005002000                        0.0   0.000000  0.000000      2020
# ...                                ...        ...       ...       ...
# 36085030301                        0.0   0.021161  0.016526      2026
# 36085030302                        0.0   0.004528  0.022034      2026
# 36085031901                        0.0   0.054600  0.000000      2026
# 36085031902                        0.0   0.040412  0.000000      2026
# 36085032300                        0.0  -0.019439  0.011017      2026
#
# [6440 rows x 19 columns]

# %% [markdown]
# ## More Feature Engineering Yada Yada

# %%
# save features
# df_train.to_pickle('Data/Cleaned/post_feat_engineering.pkl')
