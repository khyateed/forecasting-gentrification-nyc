# %%
# !pip install libpysal

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import libpysal
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_parquet('Data/Cleaned/after_kriging.parquet')
labels = pd.read_parquet('Data/Cleaned/labels_udp.parquet')
df
# Out:
#                                                 NAME     total_pop  \
# 0             Census Tract 1, Bronx County, New York  11517.000000
# 1             Census Tract 2, Bronx County, New York   4286.000000
# 2             Census Tract 4, Bronx County, New York   4893.000000
# 3            Census Tract 16, Bronx County, New York   5140.000000
# 4                                               None   4456.582103
# ...                                              ...           ...
# 2320  Census Tract 303.02; Richmond County; New York   6502.000000
# 2321  Census Tract 319.01; Richmond County; New York   3888.000000
# 2322  Census Tract 319.02; Richmond County; New York   4502.000000
# 2323     Census Tract 323; Richmond County; New York   1078.000000
# 2324    Census Tract 9901; Richmond County; New York      0.000000
#
#       percent_hh_income_assist  percent_hh_snap  percent_hh_english  \
# 0                     0.051048         0.223460            0.310196
# 1                     0.039322         0.102544            0.265227
# 2                     0.003919         0.099935            0.308295
# 3                     0.037821         0.222895            0.379223
# 4                     0.090314         0.345251            0.425018
# ...                        ...              ...                 ...
# 2320                  0.073832         0.151869            0.403271
# 2321                  0.272433         0.491512            0.621665
# 2322                  0.219144         0.463476            0.544710
# 2323                  0.028698         0.233996            0.501104
# 2324                  0.037974         0.199912            0.443741
#
#       percent_work_agriculture  percent_work_construction  \
# 0                     0.001382                   0.050642
# 1                     0.000000                   0.083885
# 2                     0.000000                   0.075145
# 3                     0.000000                   0.050652
# 4                     0.002133                   0.057241
# ...                        ...                        ...
# 2320                  0.000000                   0.044951
# 2321                  0.000000                   0.027620
# 2322                  0.000000                   0.032307
# 2323                  0.000000                   0.025135
# 2324                  0.000346                   0.055618
#
#       percent_work_retail  percent_work_finance  percent_work_stem  \
# 0                0.122766              0.095326           0.095825
# 1                0.192053              0.113687           0.080574
# 2                0.047481              0.114368           0.087531
# 3                0.084253              0.038114           0.024574
# 4                0.120698              0.061229           0.082515
# ...                   ...                   ...                ...
# 2320             0.047557              0.041694           0.069381
# 2321             0.167139              0.014873           0.172096
# 2322             0.202423              0.089854           0.036345
# 2323             0.037702              0.138241           0.114901
# 2324             0.083573              0.088717           0.126814
#
#       percent_work_edu_health  percent_work_art  percent_out_of_county  \
# 0                    0.243203          0.100514               0.583138
# 1                    0.229581          0.045254               0.016799
# 2                    0.384393          0.029315               0.036787
# 3                    0.451354          0.048646               0.003502
# 4                    0.292372          0.128216               0.031838
# ...                       ...               ...                    ...
# 2320                 0.424104          0.121824               0.010766
# 2321                 0.308074          0.138810               0.000000
# 2322                 0.334679          0.054518               0.030431
# 2323                 0.301616          0.016158               0.000000
# 2324                 0.302410          0.085188               0.022468
#
#       percent_moved_within_county  percent_public_transit  \
# 0                        0.191282                0.000000
# 1                        0.049930                0.135091
# 2                        0.055590                0.192520
# 3                        0.059533                0.172568
# 4                        0.060921                0.250265
# ...                           ...                     ...
# 2320                     0.018917                0.131959
# 2321                     0.005401                0.212449
# 2322                     0.009107                0.160817
# 2323                     0.013915                0.306122
# 2324                     0.049821                0.151912
#
#       percent_drive_commute  percent_bike_commute  percent_walk_commute  \
# 0                  0.000000              0.000000              0.000000
# 1                  0.269482              0.000000              0.006300
# 2                  0.274474              0.003679              0.012058
# 3                  0.176459              0.000000              0.007004
# 4                  0.050562              0.003455              0.030181
# ...                     ...                   ...                   ...
# 2320               0.289449              0.000000              0.004922
# 2321               0.123457              0.000000              0.000000
# 2322               0.228787              0.000000              0.021324
# 2323               0.190167              0.000000              0.010204
# 2324               0.254705              0.004194              0.031218
#
#       percent_wfh  percent_white  percent_black  percent_native  \
# 0        0.000000       0.140662       0.564557        0.001216
# 1        0.007933       0.145124       0.309146        0.008866
# 2        0.000000       0.114654       0.230738        0.000000
# 3        0.006226       0.191245       0.357977        0.000000
# 4        0.006441       0.241556       0.435755        0.004220
# ...           ...            ...            ...             ...
# 2320     0.033528       0.401723       0.246232        0.000000
# 2321     0.015689       0.230195       0.435442        0.000000
# 2322     0.008663       0.161040       0.575744        0.009996
# 2323     0.007421       0.208720       0.242115        0.000000
# 2324     0.052554       0.684088       0.052157        0.002791
#
#       percent_asian  percent_pacific  percent_latino  percent_bachelors  \
# 0          0.018755         0.000000        0.348962           0.014066
# 1          0.042697         0.000000        0.715119           0.059729
# 2          0.023503         0.000000        0.715308           0.103617
# 3          0.000000         0.000000        0.621401           0.046109
# 4          0.026521         0.000213        0.532698           0.045966
# ...             ...              ...             ...                ...
# 2320       0.119809         0.000000        0.349739           0.179791
# 2321       0.029835         0.000000        0.466049           0.043210
# 2322       0.035096         0.000000        0.338960           0.157263
# 2323       0.045455         0.000000        0.414657           0.101113
# 2324       0.152080         0.000100        0.162295           0.163688
#
#       percent_grad  percent_born_citizen  percent_naturalized_citizen  \
# 0         0.001823              0.763220                     0.044022
# 1         0.023098              0.648157                     0.170089
# 2         0.061312              0.680564                     0.103209
# 3         0.042218              0.625097                     0.138132
# 4         0.015799              0.647966                     0.073836
# ...            ...                   ...                          ...
# 2320      0.067518              0.621501                     0.237773
# 2321      0.048354              0.785751                     0.103395
# 2322      0.051977              0.724789                     0.145935
# 2323      0.136364              0.775510                     0.144712
# 2324      0.119126              0.617116                     0.262323
#
#       percent_not_citizen  percent_same_house_1yr  percent_out_of_state  \
# 0                0.110793                0.194235              0.030564
# 1                0.067429                0.905973              0.003733
# 2                0.087472                0.882690              0.000000
# 3                0.094553                0.924125              0.005837
# 4                0.167280                0.882765              0.011179
# ...                   ...                     ...                   ...
# 2320             0.089511                0.961858              0.000000
# 2321             0.030864                0.978652              0.007973
# 2322             0.103287                0.957574              0.000000
# 2323             0.051020                0.984230              0.000000
# 2324             0.110901                0.895079              0.014694
#
#         med_income  med_rent_acs    med_age  percent_hh_rented      med_value  \
# 0     43837.207255   1177.485307  31.400000           0.001878  462621.097233
# 1     59826.000000   1273.000000  29.000000           0.004626  392500.000000
# 2     71968.000000   1330.000000  36.100000           0.064010  393700.000000
# 3     30355.000000    823.000000  40.200000           0.022693  378100.000000
# 4     30851.843530    671.242573  31.914041           0.010499  482173.640895
# ...            ...           ...        ...                ...            ...
# 2320  91607.000000   2093.000000  39.500000           0.202336  475500.000000
# 2321  49161.000000    527.000000  31.300000           0.780922  399200.000000
# 2322  65921.000000    826.000000  36.300000           0.475441  476800.000000
# 2323  81691.000000   2357.000000  44.200000           0.293598  261500.000000
# 2324  75202.582036   2002.222171  44.732485           0.502755  752345.535650
#
#       percent_hh_electric  percent_hh_solar  year  med_hh_age  med_hh_tenure  \
# 0                0.098306          0.000000  2010   78.695256       24.42752
# 1                0.021588          0.000000  2010   77.000000       23.00000
# 2                0.008491          0.000000  2010   47.000000       23.00000
# 3                0.095310          0.000000  2010   57.000000       27.00000
# 4                0.107019          0.000000  2010   62.219022       25.00895
# ...                   ...               ...   ...         ...            ...
# 2320             0.049065          0.002336  2023   40.000000       17.00000
# 2321             0.031528          0.000000  2023   67.000000       16.00000
# 2322             0.025819          0.000000  2023   51.000000       17.00000
# 2323             0.059603          0.000000  2023   36.000000       18.00000
# 2324             0.138387          0.005693  2023   52.429042       14.48277
#
#      full_tract        GEOID  num_citibike_rides   num_trees     med_rent  \
# 0     005000100  36005000100                 0.0  441.302083  2063.183528
# 1     005000200  36005000200                 0.0  308.000000  2402.978322
# 2     005000400  36005000400                 0.0  318.000000  2325.892252
# 3     005001600  36005001600                 0.0  367.000000  2349.838702
# 4     005001901  36005001901                 0.0   68.000000  2487.701369
# ...         ...          ...                 ...         ...          ...
# 2320  085030302  36085030302                 0.0  745.000000  2065.177936
# 2321  085031901  36085031901                 0.0  523.000000  2697.255049
# 2322  085031902  36085031902                 0.0  663.000000  2697.255049
# 2323  085032300  36085032300                 0.0   94.000000  2065.177936
# 2324  085990100  36085990100                 0.0  626.418355  2697.255049
#
#       num_affordable_hous_built  num_bikelanes  num_evictions_commercial  \
# 0                           0.0            0.0                  0.308626
# 1                           0.0            2.0                  0.000000
# 2                           0.0           17.0                  0.000000
# 3                           0.0           12.0                  0.000000
# 4                           2.4           15.0                  0.000000
# ...                         ...            ...                       ...
# 2320                        0.0            0.0                  0.000000
# 2321                        0.0            7.0                  0.000000
# 2322                        0.0            0.0                  0.000000
# 2323                        0.0           20.0                  1.000000
# 2324                        0.0            0.0                  0.107411
#
#       num_evictions_residential  park_acres  num_parks     random_lat  \
# 0                      5.238882       0.000        0.0  227454.007430
# 1                      0.000000     272.835        4.0  234078.862014
# 2                      4.250000     362.538        6.0  232916.392053
# 3                      8.125000      68.147        2.0  238003.638656
# 4                     15.875000       0.000        0.0  233255.890204
# ...                         ...         ...        ...            ...
# 2320                  12.000000       4.465        1.0  165905.969574
# 2321                   3.000000       3.014        1.0  169052.876654
# 2322                  21.000000      70.871        2.0  172803.924597
# 2323                   1.000000     233.336        6.0  169458.064831
# 2324                   4.729227       0.000        0.0  150143.083511
#
#         random_lon
# 0     1.017060e+06
# 1     1.023593e+06
# 2     1.025947e+06
# 3     1.023288e+06
# 4     1.004954e+06
# ...            ...
# 2320  9.387885e+05
# 2321  9.391126e+05
# 2322  9.380643e+05
# 2323  9.366472e+05
# 2324  9.694278e+05
#
# [32550 rows x 55 columns]

# %% [markdown]
# ## Per-Capita Features

# %%
# to_change = ['num_citibike_rides','num_trees', 'num_affordable_hous_built', 'num_bikelanes',
#        'num_evictions_commercial', 'num_evictions_residential','num_parks']
# for col in to_change:
#     name = col.replace('num_','')
#     df[name+'_pc'] = df[col]/df['total_pop']
# df.drop(to_change, axis=1, inplace=True)

# %% [markdown]
# ## Generate Features for X-Year Percent Change
# **We train on a 6 year period, and predict 4 years into the future**
# - train on features 2010-2016 to predict gentrification status in 2020 (labels from 2020, eligible tracts from 2010)
# - 2011-2017
# - 2012-2018
# - train on features 2013-2019 to predict gentrification status in 2023 (labels from 2023, eligible tracts from 2013)
# - then use features 2017-2023 to predict gentrification status in 2027 (no labels, eligible tracts are taken from 2017)

# %%
df_10_16 = df[df.year.isin(['2010','2011','2012','2013','2014','2015','2016'])]  # training set
df_11_17 = df[df.year.isin(['2011','2012','2013','2014','2015','2016','2017'])]  # training set
df_12_18 = df[df.year.isin(['2012','2013','2014','2015','2016','2017','2018'])]  # training set
df_13_19 = df[df.year.isin(['2013','2014','2015','2016','2017','2018','2019'])]  # training set
df_14_20 = df[df.year.isin(['2014','2015','2016','2017','2018','2019','2020'])]  # pred set
df_15_21 = df[df.year.isin(['2015','2016','2017','2018','2019','2020','2021'])]  # pred set
df_16_22 = df[df.year.isin(['2016','2017','2018','2019','2020','2021','2022'])]  # pred set
df_17_23 = df[df.year.isin(['2017','2018','2019','2020','2021','2022','2023'])]  # pred set

df_10_16 = df_10_16.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_11_17 = df_11_17.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_12_18 = df_12_18.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_13_19 = df_13_19.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_14_20 = df_14_20.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_15_21 = df_15_21.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_16_22 = df_16_22.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())
df_17_23 = df_17_23.drop(['NAME','year', 'full_tract','random_lat', 'random_lon'], axis=1).groupby('GEOID').agg(lambda x: x.pct_change().replace([np.inf, -np.inf], np.nan).mean())

df_10_16['pred_year']='2020'
df_11_17['pred_year']='2021'
df_12_18['pred_year']='2022'
df_13_19['pred_year']='2023'
df_14_20['pred_year']='2024'
df_15_21['pred_year']='2025'
df_16_22['pred_year']='2026'
df_17_23['pred_year']='2027'

# %%
df_train = pd.concat([df_10_16,df_11_17,df_12_18, df_13_19,df_14_20,df_15_21,df_16_22, df_17_23])

# drop rows that became entirely null bc of the % change
df = df_train.dropna(how='all', subset=[ 'percent_white', 'percent_black', 'percent_native',
       'percent_asian', 'percent_pacific', 'percent_latino', 'percent_bachelors',
       'percent_grad'])

df.fillna(0, inplace=True)
df.reset_index(inplace=True)
df
# Out:
#              GEOID  total_pop  percent_hh_income_assist  percent_hh_snap  \
# 0      36005000100  -0.068661                  0.035685         0.028985
# 1      36005000200   0.034962                  0.218237         0.201764
# 2      36005000400   0.034124                  0.786830         0.168444
# 3      36005001600   0.028238                  0.105534         0.119549
# 4      36005001901   0.000644                 -0.034693         0.006081
# ...            ...        ...                       ...              ...
# 18595  36085030302  -0.001154                  0.215473         0.011413
# 18596  36085031901   0.061577                 -0.040771        -0.050215
# 18597  36085031902  -0.019885                  0.048796         0.054946
# 18598  36085032300  -0.006561                 -0.142393         0.053304
# 18599  36085990100   0.000000                  0.011287         0.011354
#
#        percent_hh_english  percent_work_agriculture  \
# 0                0.001017                  0.199477
# 1               -0.026817                 -0.211255
# 2               -0.006987                  0.000000
# 3               -0.037455                  0.000000
# 4               -0.001591                 -0.081312
# ...                   ...                       ...
# 18595           -0.021104                  0.000000
# 18596           -0.006222                  0.000000
# 18597           -0.015290                  0.000000
# 18598           -0.043870                  0.000000
# 18599           -0.021208                  1.240380
#
#        percent_work_construction  percent_work_retail  percent_work_finance  \
# 0                       0.045892            -0.017763              0.035731
# 1                      -0.143559            -0.051058              0.005439
# 2                      -0.086546             0.085892             -0.119376
# 3                      -0.068067             0.070625             -0.016419
# 4                      -0.047796            -0.014341             -0.055569
# ...                          ...                  ...                   ...
# 18595                  -0.036738            -0.134240             -0.067538
# 18596                   1.556189             0.042698              0.185330
# 18597                   0.013640             0.195240              0.040898
# 18598                   0.097549            -0.031988              0.371914
# 18599                  -0.016595            -0.012461             -0.004150
#
#        percent_work_stem  percent_work_edu_health  percent_work_art  \
# 0               0.022690                 0.021284          0.054678
# 1               0.075584                 0.050176          0.071833
# 2               0.065526                -0.033501          0.236460
# 3               0.270917                -0.013170          0.057567
# 4               0.035664                -0.007433          0.090601
# ...                  ...                      ...               ...
# 18595           0.016564                 0.077345          0.148286
# 18596           0.093050                 0.046607          0.215565
# 18597           0.096007                -0.049353         -0.125466
# 18598           0.182109                -0.041365         -0.224979
# 18599           0.013607                 0.027765          0.001622
#
#        percent_out_of_county  percent_moved_within_county  \
# 0                  -0.014333                     0.065448
# 1                  -0.077578                    -0.105136
# 2                  -0.107590                    -0.004790
# 3                   0.232766                    -0.104326
# 4                  -0.102033                    -0.018727
# ...                      ...                          ...
# 18595               0.698988                    -0.034859
# 18596              -0.330398                    -0.189565
# 18597               0.198931                     0.014783
# 18598               0.000000                     1.860428
# 18599               0.039024                    -0.001013
#
#        percent_public_transit  percent_drive_commute  percent_bike_commute  \
# 0                    0.000000               0.000000              0.000000
# 1                    0.033405              -0.021183              0.000000
# 2                    0.028070              -0.028604             -0.187822
# 3                   -0.015358              -0.022066              0.000000
# 4                    0.016370              -0.032029              0.232876
# ...                       ...                    ...                   ...
# 18595                0.041904              -0.004503              0.000000
# 18596                0.168862               0.013573             -0.225023
# 18597                0.004287               0.073021              0.000000
# 18598                0.091209              -0.054103              0.000000
# 18599               -0.025013               0.024612              0.201101
#
#        percent_walk_commute  percent_wfh  percent_white  percent_black  \
# 0                  0.000000     0.000000      -0.006464       0.018035
# 1                  0.138279    -0.377954       0.214509      -0.026615
# 2                 -0.041648     2.037930       0.255629       0.070771
# 3                  0.312918    -0.095215       0.168040       0.005470
# 4                  0.007768     0.041536      -0.064106      -0.018095
# ...                     ...          ...            ...            ...
# 18595              0.209163     0.946175      -0.045150       0.086675
# 18596             -0.275365    -0.003081       0.011597      -0.048561
# 18597              0.161195     0.009269      -0.115204       0.011083
# 18598             -0.014034     0.432146      -0.110069      -0.082349
# 18599             -0.028269     0.192493      -0.015924      -0.132290
#
#        percent_native  percent_asian  percent_pacific  percent_latino  \
# 0            0.277300      -0.000033         0.000000       -0.024075
# 1           -0.298942      -0.017225         0.000000        0.009071
# 2            0.083326      -0.038641         0.000000       -0.016291
# 3            0.000000       0.000000         0.000000        0.013476
# 4            0.106253      -0.061774         0.422531        0.003428
# ...               ...            ...              ...             ...
# 18595        0.000000       0.011771         0.000000        0.008026
# 18596        0.000000       0.183167         0.000000        0.075288
# 18597       -0.083033       0.477168         0.000000       -0.003335
# 18598        0.000000       0.570565         0.000000        0.076573
# 18599        0.176376       0.073109         0.963076        0.014327
#
#        percent_bachelors  percent_grad  percent_born_citizen  \
# 0              -0.124830      0.449510              0.002733
# 1               0.057625      0.148837             -0.027422
# 2               0.000209      0.032225              0.000973
# 3               0.015757     -0.076782             -0.031302
# 4               0.049573      0.224663              0.004055
# ...                  ...           ...                   ...
# 18595           0.055342      0.008809             -0.009526
# 18596          -0.061371      0.433025              0.009850
# 18597           0.095097      0.006309             -0.007570
# 18598           0.122195      0.421512             -0.010318
# 18599           0.020069      0.022516             -0.005704
#
#        percent_naturalized_citizen  percent_not_citizen  \
# 0                         0.025448             0.010323
# 1                         0.023382             0.149468
# 2                         0.054771             0.012176
# 3                         0.045230             0.142282
# 4                         0.049740            -0.004173
# ...                            ...                  ...
# 18595                     0.082499            -0.051934
# 18596                     0.088852            -0.103608
# 18597                     0.107293             0.013515
# 18598                     0.160294             0.083382
# 18599                     0.020204             0.000024
#
#        percent_same_house_1yr  percent_out_of_state  med_income  med_rent_acs  \
# 0                   -0.014150             -0.050057    0.005722      0.049193
# 1                    0.009212             -0.077517    0.030404     -0.003322
# 2                    0.007979             -0.229897    0.011434      0.009918
# 3                    0.004117             -0.403649    0.008068      0.023547
# 4                    0.002864             -0.171264   -0.018268      0.078083
# ...                       ...                   ...         ...           ...
# 18595                0.002615             -0.173023    0.033478      0.025459
# 18596                0.004566             -0.163036    0.465666     -0.063389
# 18597                0.005042             -1.000000    0.120181      0.058746
# 18598               -0.001104             -0.376098    0.043610      0.121217
# 18599               -0.001137              0.225599    0.018685      0.063077
#
#         med_age  percent_hh_rented  med_value  percent_hh_electric  \
# 0      0.004397           1.089373   0.008277            -0.005696
# 1      0.049306           1.106573   0.001691             0.311270
# 2      0.015270          -0.394797  -0.017437             1.049936
# 3     -0.013855           7.142181   0.003578             0.013124
# 4      0.001804           7.661378  -0.023169            -0.001365
# ...         ...                ...        ...                  ...
# 18595  0.025387          -0.050505   0.064139            -0.006120
# 18596  0.011333           0.009512   0.050791             1.679250
# 18597  0.047016          -0.021044   0.090066            -0.035160
# 18598  0.016846           0.057573   0.010175             0.176348
# 18599  0.010471          -0.004578   0.093014             0.082210
#
#        percent_hh_solar  med_hh_age  med_hh_tenure  num_citibike_rides  \
# 0             12.906525   -0.007878      -0.034566                 0.0
# 1              0.000000   -0.021834      -0.021378                 0.0
# 2              0.000000   -0.060346      -0.014822                 0.0
# 3              0.000000   -0.017877      -0.040687                 0.0
# 4             -0.010289    0.026425      -0.039251                 0.0
# ...                 ...         ...            ...                 ...
# 18595         -0.066851   -0.011909      -0.032434                 0.0
# 18596          0.000000    0.010760      -0.012765                 0.0
# 18597         -0.247456   -0.000359      -0.016329                 0.0
# 18598          0.000000    0.020666      -0.008333                 0.0
# 18599         22.746887    0.006284      -0.055770                 0.0
#
#        num_trees  med_rent  num_affordable_hous_built  num_bikelanes  \
# 0       0.040565  0.013164                   0.000000       0.000000
# 1       0.039684  0.000384                   0.000000       0.000000
# 2       0.065020 -0.002948                   0.000000       0.070962
# 3       0.063187  0.029170                   0.000000       0.069444
# 4       0.055470  0.016927                  -0.520833       0.000000
# ...          ...       ...                        ...            ...
# 18595   0.002710  0.018248                   0.000000       0.000000
# 18596   0.038060  0.054117                   0.000000       0.000000
# 18597   0.039666  0.040176                   0.000000       0.000000
# 18598  -0.019825  0.018248                   0.000000       0.105556
# 18599   0.016053  0.032684                   0.000000       0.000000
#
#        num_evictions_commercial  num_evictions_residential  park_acres  \
# 0                      0.144316                   0.082033         0.0
# 1                      0.000000                   0.000000         0.0
# 2                      0.000000                   0.051681         0.0
# 3                      0.000000                   0.106212         0.0
# 4                      0.000000                   0.048778         0.0
# ...                         ...                        ...         ...
# 18595                 -1.000000                   0.547619         0.0
# 18596                  0.000000                  -0.101082         0.0
# 18597                 -1.000000                   1.545939         0.0
# 18598                  0.000000                  -0.166667         0.0
# 18599                  1.155088                  -0.079509         0.0
#
#        num_parks pred_year
# 0            0.0      2020
# 1            0.0      2020
# 2            0.0      2020
# 3            0.0      2020
# 4            0.0      2020
# ...          ...       ...
# 18595        0.0      2027
# 18596        0.0      2027
# 18597        0.0      2027
# 18598        0.0      2027
# 18599        0.0      2027
#
# [18600 rows x 51 columns]

# %% [markdown]
# ## Spatial Lag Feature
# Feature to measure proximity to already-gentrified / super-gentrified tracts

# %%
# Load the census tract shapefile
gdf = gpd.read_file('Data/Raw/tracts2020_shapefile/nyct2020.shp')
gdf = gdf.to_crs(epsg = 4326)
gdf = gdf.merge(labels, on='GEOID')

# %%
# Create a weights matrix based on contiguity (e.g., Queen's case)
w = libpysal.weights.contiguity.Queen.from_dataframe(gdf)
    
# Row-standardize the weights (optional, but often recommended)
w.transform = 'R'

# Calculate the spatial lag
spatial_lag = libpysal.weights.spatial_lag.lag_spatial(w, gdf['vulnerable'])

# Add the spatial lag as a new column in the GeoDataFrame
gdf['lag_' + 'vulnerable'] = spatial_lag


# Identify observations with no neighbors
islands = w.islands
if islands:
    # Assign the original value to the spatial lag for islands
    gdf.loc[gdf.index.isin(islands), 'lag_' + 'vulnerable'] = gdf.loc[gdf.index.isin(islands), 'vulnerable']

lag_df = gdf[['NTAName','GEOID','vulnerable','pred_year','lag_vulnerable']]

# %%
# add spatial lag feature to the main df
df = df.merge(lag_df[['lag_vulnerable','GEOID','pred_year']], on=['GEOID','pred_year'])
df
# Out:
#              GEOID  total_pop  percent_hh_income_assist  percent_hh_snap  \
# 0      36005000100  -0.068661                  0.035685         0.028985
# 1      36005000200   0.034962                  0.218237         0.201764
# 2      36005000400   0.034124                  0.786830         0.168444
# 3      36005001600   0.028238                  0.105534         0.119549
# 4      36005001901   0.000644                 -0.034693         0.006081
# ...            ...        ...                       ...              ...
# 18595  36085030302  -0.001154                  0.215473         0.011413
# 18596  36085031901   0.061577                 -0.040771        -0.050215
# 18597  36085031902  -0.019885                  0.048796         0.054946
# 18598  36085032300  -0.006561                 -0.142393         0.053304
# 18599  36085990100   0.000000                  0.011287         0.011354
#
#        percent_hh_english  percent_work_agriculture  \
# 0                0.001017                  0.199477
# 1               -0.026817                 -0.211255
# 2               -0.006987                  0.000000
# 3               -0.037455                  0.000000
# 4               -0.001591                 -0.081312
# ...                   ...                       ...
# 18595           -0.021104                  0.000000
# 18596           -0.006222                  0.000000
# 18597           -0.015290                  0.000000
# 18598           -0.043870                  0.000000
# 18599           -0.021208                  1.240380
#
#        percent_work_construction  percent_work_retail  percent_work_finance  \
# 0                       0.045892            -0.017763              0.035731
# 1                      -0.143559            -0.051058              0.005439
# 2                      -0.086546             0.085892             -0.119376
# 3                      -0.068067             0.070625             -0.016419
# 4                      -0.047796            -0.014341             -0.055569
# ...                          ...                  ...                   ...
# 18595                  -0.036738            -0.134240             -0.067538
# 18596                   1.556189             0.042698              0.185330
# 18597                   0.013640             0.195240              0.040898
# 18598                   0.097549            -0.031988              0.371914
# 18599                  -0.016595            -0.012461             -0.004150
#
#        percent_work_stem  percent_work_edu_health  percent_work_art  \
# 0               0.022690                 0.021284          0.054678
# 1               0.075584                 0.050176          0.071833
# 2               0.065526                -0.033501          0.236460
# 3               0.270917                -0.013170          0.057567
# 4               0.035664                -0.007433          0.090601
# ...                  ...                      ...               ...
# 18595           0.016564                 0.077345          0.148286
# 18596           0.093050                 0.046607          0.215565
# 18597           0.096007                -0.049353         -0.125466
# 18598           0.182109                -0.041365         -0.224979
# 18599           0.013607                 0.027765          0.001622
#
#        percent_out_of_county  percent_moved_within_county  \
# 0                  -0.014333                     0.065448
# 1                  -0.077578                    -0.105136
# 2                  -0.107590                    -0.004790
# 3                   0.232766                    -0.104326
# 4                  -0.102033                    -0.018727
# ...                      ...                          ...
# 18595               0.698988                    -0.034859
# 18596              -0.330398                    -0.189565
# 18597               0.198931                     0.014783
# 18598               0.000000                     1.860428
# 18599               0.039024                    -0.001013
#
#        percent_public_transit  percent_drive_commute  percent_bike_commute  \
# 0                    0.000000               0.000000              0.000000
# 1                    0.033405              -0.021183              0.000000
# 2                    0.028070              -0.028604             -0.187822
# 3                   -0.015358              -0.022066              0.000000
# 4                    0.016370              -0.032029              0.232876
# ...                       ...                    ...                   ...
# 18595                0.041904              -0.004503              0.000000
# 18596                0.168862               0.013573             -0.225023
# 18597                0.004287               0.073021              0.000000
# 18598                0.091209              -0.054103              0.000000
# 18599               -0.025013               0.024612              0.201101
#
#        percent_walk_commute  percent_wfh  percent_white  percent_black  \
# 0                  0.000000     0.000000      -0.006464       0.018035
# 1                  0.138279    -0.377954       0.214509      -0.026615
# 2                 -0.041648     2.037930       0.255629       0.070771
# 3                  0.312918    -0.095215       0.168040       0.005470
# 4                  0.007768     0.041536      -0.064106      -0.018095
# ...                     ...          ...            ...            ...
# 18595              0.209163     0.946175      -0.045150       0.086675
# 18596             -0.275365    -0.003081       0.011597      -0.048561
# 18597              0.161195     0.009269      -0.115204       0.011083
# 18598             -0.014034     0.432146      -0.110069      -0.082349
# 18599             -0.028269     0.192493      -0.015924      -0.132290
#
#        percent_native  percent_asian  percent_pacific  percent_latino  \
# 0            0.277300      -0.000033         0.000000       -0.024075
# 1           -0.298942      -0.017225         0.000000        0.009071
# 2            0.083326      -0.038641         0.000000       -0.016291
# 3            0.000000       0.000000         0.000000        0.013476
# 4            0.106253      -0.061774         0.422531        0.003428
# ...               ...            ...              ...             ...
# 18595        0.000000       0.011771         0.000000        0.008026
# 18596        0.000000       0.183167         0.000000        0.075288
# 18597       -0.083033       0.477168         0.000000       -0.003335
# 18598        0.000000       0.570565         0.000000        0.076573
# 18599        0.176376       0.073109         0.963076        0.014327
#
#        percent_bachelors  percent_grad  percent_born_citizen  \
# 0              -0.124830      0.449510              0.002733
# 1               0.057625      0.148837             -0.027422
# 2               0.000209      0.032225              0.000973
# 3               0.015757     -0.076782             -0.031302
# 4               0.049573      0.224663              0.004055
# ...                  ...           ...                   ...
# 18595           0.055342      0.008809             -0.009526
# 18596          -0.061371      0.433025              0.009850
# 18597           0.095097      0.006309             -0.007570
# 18598           0.122195      0.421512             -0.010318
# 18599           0.020069      0.022516             -0.005704
#
#        percent_naturalized_citizen  percent_not_citizen  \
# 0                         0.025448             0.010323
# 1                         0.023382             0.149468
# 2                         0.054771             0.012176
# 3                         0.045230             0.142282
# 4                         0.049740            -0.004173
# ...                            ...                  ...
# 18595                     0.082499            -0.051934
# 18596                     0.088852            -0.103608
# 18597                     0.107293             0.013515
# 18598                     0.160294             0.083382
# 18599                     0.020204             0.000024
#
#        percent_same_house_1yr  percent_out_of_state  med_income  med_rent_acs  \
# 0                   -0.014150             -0.050057    0.005722      0.049193
# 1                    0.009212             -0.077517    0.030404     -0.003322
# 2                    0.007979             -0.229897    0.011434      0.009918
# 3                    0.004117             -0.403649    0.008068      0.023547
# 4                    0.002864             -0.171264   -0.018268      0.078083
# ...                       ...                   ...         ...           ...
# 18595                0.002615             -0.173023    0.033478      0.025459
# 18596                0.004566             -0.163036    0.465666     -0.063389
# 18597                0.005042             -1.000000    0.120181      0.058746
# 18598               -0.001104             -0.376098    0.043610      0.121217
# 18599               -0.001137              0.225599    0.018685      0.063077
#
#         med_age  percent_hh_rented  med_value  percent_hh_electric  \
# 0      0.004397           1.089373   0.008277            -0.005696
# 1      0.049306           1.106573   0.001691             0.311270
# 2      0.015270          -0.394797  -0.017437             1.049936
# 3     -0.013855           7.142181   0.003578             0.013124
# 4      0.001804           7.661378  -0.023169            -0.001365
# ...         ...                ...        ...                  ...
# 18595  0.025387          -0.050505   0.064139            -0.006120
# 18596  0.011333           0.009512   0.050791             1.679250
# 18597  0.047016          -0.021044   0.090066            -0.035160
# 18598  0.016846           0.057573   0.010175             0.176348
# 18599  0.010471          -0.004578   0.093014             0.082210
#
#        percent_hh_solar  med_hh_age  med_hh_tenure  num_citibike_rides  \
# 0             12.906525   -0.007878      -0.034566                 0.0
# 1              0.000000   -0.021834      -0.021378                 0.0
# 2              0.000000   -0.060346      -0.014822                 0.0
# 3              0.000000   -0.017877      -0.040687                 0.0
# 4             -0.010289    0.026425      -0.039251                 0.0
# ...                 ...         ...            ...                 ...
# 18595         -0.066851   -0.011909      -0.032434                 0.0
# 18596          0.000000    0.010760      -0.012765                 0.0
# 18597         -0.247456   -0.000359      -0.016329                 0.0
# 18598          0.000000    0.020666      -0.008333                 0.0
# 18599         22.746887    0.006284      -0.055770                 0.0
#
#        num_trees  med_rent  num_affordable_hous_built  num_bikelanes  \
# 0       0.040565  0.013164                   0.000000       0.000000
# 1       0.039684  0.000384                   0.000000       0.000000
# 2       0.065020 -0.002948                   0.000000       0.070962
# 3       0.063187  0.029170                   0.000000       0.069444
# 4       0.055470  0.016927                  -0.520833       0.000000
# ...          ...       ...                        ...            ...
# 18595   0.002710  0.018248                   0.000000       0.000000
# 18596   0.038060  0.054117                   0.000000       0.000000
# 18597   0.039666  0.040176                   0.000000       0.000000
# 18598  -0.019825  0.018248                   0.000000       0.105556
# 18599   0.016053  0.032684                   0.000000       0.000000
#
#        num_evictions_commercial  num_evictions_residential  park_acres  \
# 0                      0.144316                   0.082033         0.0
# 1                      0.000000                   0.000000         0.0
# 2                      0.000000                   0.051681         0.0
# 3                      0.000000                   0.106212         0.0
# 4                      0.000000                   0.048778         0.0
# ...                         ...                        ...         ...
# 18595                 -1.000000                   0.547619         0.0
# 18596                  0.000000                  -0.101082         0.0
# 18597                 -1.000000                   1.545939         0.0
# 18598                  0.000000                  -0.166667         0.0
# 18599                  1.155088                  -0.079509         0.0
#
#        num_parks pred_year  lag_vulnerable
# 0            0.0      2020        1.000000
# 1            0.0      2020        0.574468
# 2            0.0      2020        0.723404
# 3            0.0      2020        0.714286
# 4            0.0      2020        0.978723
# ...          ...       ...             ...
# 18595        0.0      2027        0.297872
# 18596        0.0      2027        0.531915
# 18597        0.0      2027        0.774194
# 18598        0.0      2027        0.381818
# 18599        0.0      2027        0.000000
#
# [18600 rows x 52 columns]

# %%
# save features
# df.to_parquet('Data/Cleaned/post_feat_engineering.parquet')
