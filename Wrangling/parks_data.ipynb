# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely import wkt

# %%
df = pd.read_csv('Data/Raw/Parks_Data.csv')

# drop rows with no date
df.dropna(subset=['ACQUISITIONDATE'], inplace=True)
df.sample(5)
# Out:
#              ACQUISITIONDATE  ACRES              ADDRESS BOROUGH CLASS  \
# 504   09/12/1941 12:00:00 AM  0.943     1480 PARK AVENUE       M  PARK
# 1332  11/24/1997 12:00:00 AM  1.868  786 EAST 181 STREET       X  PARK
# 492   12/31/1949 12:00:00 AM  0.192   328 EAST 42 STREET       M  PARK
# 1769  03/04/2003 12:00:00 AM  0.680                  NaN       X  PARK
# 1304  07/26/2018 12:00:00 AM  0.321  480 BEACH 43 STREET       Q  PARK
#
#      COMMUNITYBOARD COUNCILDISTRICT DEPARTMENT                        EAPPLY  \
# 504             111               8       M-11       Peter Minuit Playground
# 1332            206              15       X-06                    Mapes Park
# 492             106               4       M-06        Tudor Grove Playground
# 1769            206              15       X-06  West Farms Soldiers Cemetery
# 1304            414              31       Q-14                           NaN
#
#          GISOBJID  ... PIP_RATABLE PRECINCT RETIRED  \
# 504   100004991.0  ...        True     23.0   False
# 1332  100005181.0  ...        True     48.0   False
# 492   100004409.0  ...        True     17.0   False
# 1769  100004210.0  ...       False     48.0   False
# 1304  100042706.0  ...       False    101.0   False
#
#                           SIGNNAME        SUBCATEGORY  \
# 504        Peter Minuit Playground                JOP
# 1332                    Mapes Park  Neighborhood Park
# 492         Tudor Grove Playground  Neighborhood Plgd
# 1769  West Farms Soldiers Cemetery           Cemetery
# 1304            Edgemere Coalition                NaN
#
#                      TYPECATEGORY  US_CONGRESS  WATERFRONT  ZIPCODE  \
# 504   Jointly Operated Playground         13.0       False    10029
# 1332            Neighborhood Park         15.0       False    10460
# 492                    Playground         12.0       False    10017
# 1769                     Cemetery         15.0       False    10460
# 1304                       Garden          5.0       False    11691
#
#                                            multipolygon
# 504   MULTIPOLYGON (((-73.94713332007458 40.79440606...
# 1332  MULTIPOLYGON (((-73.88506332614014 40.84731526...
# 492   MULTIPOLYGON (((-73.97138027879109 40.74900978...
# 1769  MULTIPOLYGON (((-73.87880008486053 40.84376663...
# 1304  MULTIPOLYGON (((-73.77476815216733 40.59802335...
#
# [5 rows x 34 columns]

# %%
# change to datetime
df['year'] = pd.to_datetime(df['ACQUISITIONDATE']).dt.year

# trim columns
df = df[['year', 'ACRES','ZIPCODE', 'multipolygon', 'SIGNNAME']]
df
# Out:
# /var/folders/w0/4r14_1sj0j7fl6nz7v1nwgkr0000gp/T/ipykernel_80096/694775813.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['year'] = pd.to_datetime(df['ACQUISITIONDATE']).dt.year
#       year    ACRES                     ZIPCODE  \
# 0     1916    0.545                       10034
# 1     1936    2.213                       10457
# 2     2002    0.114                       10460
# 3     2006    6.219                       11373
# 4     1902    3.312                       10021
# ...    ...      ...                         ...
# 2047  1934  897.690  11354, 11355, 11367, 11368
# 2048  1914  109.609                       11434
# 2049  1926    1.395                       10467
# 2050  1981    1.774                       11233
# 2051  1888   80.936                10458, 10467
#
#                                            multipolygon  \
# 0     MULTIPOLYGON (((-73.92305320407046 40.86718368...
# 1     MULTIPOLYGON (((-73.88696663993288 40.85003709...
# 2     MULTIPOLYGON (((-73.88234391814649 40.84707387...
# 3     MULTIPOLYGON (((-73.88436854859785 40.72890922...
# 4     MULTIPOLYGON (((-73.94903734207423 40.76900910...
# ...                                                 ...
# 2047  MULTIPOLYGON (((-73.84509867168501 40.75388350...
# 2048  MULTIPOLYGON (((-73.78439768325394 40.67917896...
# 2049  MULTIPOLYGON (((-73.8663734574437 40.877463712...
# 2050  MULTIPOLYGON (((-73.92831562852702 40.67987313...
# 2051  MULTIPOLYGON (((-73.88464925581968 40.87988370...
#
#                              SIGNNAME
# 0                Dyckman House Museum
# 1                  Belmont Playground
# 2              Volky Garden & Flowers
# 3                       Elmhurst Park
# 4                       John Jay Park
# ...                               ...
# 2047     Flushing Meadows Corona Park
# 2048                Baisley Pond Park
# 2049             Marcus Garvey Square
# 2050  Jackie Robinson Park Playground
# 2051                  Mosholu Parkway
#
# [1962 rows x 5 columns]

# %% [markdown]
# ## Spatial Join Polygons to Census Tracts

# %%
# Load the census tract shapefile
tracts = gpd.read_file('Data/Raw/tracts2020_shapefile/nyct2020.shp')
tracts = tracts.to_crs(epsg = 4326)

# %%
geometry = wkt.loads(df['multipolygon'])
geo_df = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# Perform a spatial join to match points to census tracts
geo_df = gpd.sjoin(geo_df, tracts, how='inner', predicate="intersects")
geo_df = geo_df[['year','ACRES', 'GEOID']]
geo_df
# Out:
#       year   ACRES        GEOID
# 0     1916   0.545  36061029500
# 1     1936   2.213  36005037300
# 2     2002   0.114  36005036300
# 3     2006   6.219  36081049900
# 4     1902   3.312  36061013202
# ...    ...     ...          ...
# 2049  1926   1.395  36005037800
# 2050  1981   1.774  36047038100
# 2051  1888  80.936  36005042500
# 2051  1888  80.936  36005041900
# 2051  1888  80.936  36005042100
#
# [2572 rows x 3 columns]

# %% [markdown]
# ### Adjust Dates

# %%
geo_df['num_parks'] = 1

# %%
b4 = geo_df[geo_df.year<2009]
df_09 = b4.groupby(['GEOID'])[['ACRES', 'num_parks']].sum().reset_index()
df_09['year'] = '2009'
df_09.sort_values('GEOID')
# Out:
#             GEOID       ACRES  num_parks  year
# 0     36005000200  270.675000          3  2009
# 1     36005000400  362.538000          6  2009
# 2     36005001600   68.147000          2  2009
# 3     36005001902    3.400000          2  2009
# 4     36005001904   51.504366          2  2009
# ...           ...         ...        ...   ...
# 1268  36085030301  200.081000          2  2009
# 1269  36085030302    4.465000          1  2009
# 1270  36085031901    3.014000          1  2009
# 1271  36085031902    0.271000          1  2009
# 1272  36085032300  162.736000          5  2009
#
# [1273 rows x 4 columns]

# %%
df_list = [df_09]
for yr in [2010,2011, 2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]:
    df_yr = geo_df[geo_df.year==yr]
    df = pd.concat([df_list[-1], df_yr])
    grouped = df.groupby(['GEOID'])[['ACRES', 'num_parks']].sum().reset_index()
    grouped['year'] = str(yr)
    df_list.append(grouped)

# %%
df_out = pd.concat(df_list).sort_values(['GEOID', 'year'])
df_out.rename(columns={'ACRES':'park_acres'}, inplace=True)

# %%
df_out.sample(5)
# Out:
#             GEOID  park_acres  num_parks  year
# 0     36005000200     270.675          3  2009
# 0     36005000200     272.835          4  2010
# 0     36005000200     272.835          4  2011
# 0     36005000200     272.835          4  2012
# 0     36005000200     272.835          4  2013
# ...           ...         ...        ...   ...
# 1291  36085032300     233.336          6  2019
# 1291  36085032300     233.336          6  2020
# 1291  36085032300     233.336          6  2021
# 1291  36085032300     233.336          6  2022
# 1292  36085032300     233.336          6  2023
#
# [19282 rows x 4 columns]

# %%
# df_out.to_parquet('Data/Cleaned/parks.parquet')
